# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
a = 1
b = 42
x = np.arange (0.01, 1, 0.01)
y = beta.ppf(x,a,b)
plt.plot(x,y)

# %%
for x in [.5, .8, .9, .95, .98, .99, .999]:
  print(f"{x:.3f}: {beta.ppf(x, a, b):.3f}")
# Out:
# 0.500: 0.016
# 0.800: 0.038
# 0.900: 0.053
# 0.950: 0.069
# 0.980: 0.089
# 0.990: 0.104
# 0.999: 0.152
