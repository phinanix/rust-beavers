# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np

# %%
adj = 0
a = 1 - adj
b = 42 - adj
x = np.arange (0.01, 1, 0.01)
y = beta.ppf(x,a,b)
plt.plot(x,y)

# %%
for x in [.1, .2, .5, .8, .9, .95, .98, .99, .999]:
  print(f"{x:.3f}: {beta.ppf(x, a, b)}")
# Out:
# 0.100: 0.002505439839467078
# 0.200: 0.005298852985094056
# 0.500: 0.016368067555809964
# 0.800: 0.037595030128913055
# 0.900: 0.05334773969181026
# 0.950: 0.06884260784039488
# 0.980: 0.08893715993970028
# 0.990: 0.10384949805339534
# 0.999: 0.15165710175592792

# %%
a = 27
b = 57
x = np.arange (0.01, 1, 0.01)
y = beta.pdf(x,a,b)
plt.plot(x,y)

# %%
low = beta.ppf(.05, a, b)
mid = beta.ppf(.5, a, b)
high = beta.ppf(.95, a, b)
# print(f"{low:.2f} {mid:.2f} {high:.2f}")
for x in [.05, .1, .5, .9, .95]: 
  print(f"{x:.2f} {beta.ppf(x, a, b):.2f}")
# Out:
# 0.05 0.24
# 0.10 0.26
# 0.50 0.32
# 0.90 0.39
# 0.95 0.41

# %%
# current
# 90% spread = .24 - .42 = .18
# 95% spread = .21 - .45 = .24

# double samples
# 90% spread = .26 - .39 = .13
# 95% spread = .24 - .41 = .17

# %%
# goes left within 2_august_24
prior = 1
a = 9 + prior
b = 16 + prior
x = np.arange (0.01, 1, 0.01)
y = beta.pdf(x,a,b)
plt.plot(x,y)

# %%
beta.ppf(.0063, a, b)
# Out:
# np.float64(0.16570348899807277)

# %%
10292 / 62127
# Out:
# 0.16566066283580408

# %%
beta.ppf(.05, a, b)
# Out:
# np.float64(0.2256998822232372)
